# %%
# %pip install python-dotenv anthropic
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Collecting anthropic
#   Downloading anthropic-0.111.0-py3-none-any.whl.metadata (3.2 kB)
# Collecting anyio<5,>=3.5.0 (from anthropic)
#   Downloading anyio-4.14.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting distro<2,>=1.7.0 (from anthropic)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting docstring-parser<1,>=0.15 (from anthropic)
#   Downloading docstring_parser-0.18.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting httpx<1,>=0.25.0 (from anthropic)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from anthropic)
#   Downloading jiter-0.15.0-cp314-cp314-win_amd64.whl.metadata (5.3 kB)
# Collecting pydantic<3,>=1.9.0 (from anthropic)
#   Downloading pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# Collecting sniffio (from anthropic)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions<5,>=4.14 in .\.venv\Lib\site-packages (from anthropic) (4.15.0)
# Collecting idna>=2.8 (from anyio<5,>=3.5.0->anthropic)
#   Downloading idna-3.18-py3-none-any.whl.metadata (6.1 kB)
# Collecting certifi (from httpx<1,>=0.25.0->anthropic)
#   Downloading certifi-2026.6.17-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.25.0->anthropic)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.25.0->anthropic)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->anthropic)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.4 (from pydantic<3,>=1.9.0->anthropic)
#   Downloading pydantic_core-2.46.4-cp314-cp314-win_amd64.whl.metadata (6.7 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=1.9.0->anthropic)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Downloading anthropic-0.111.0-py3-none-any.whl (929 kB)
#    ---------------------------------------- 0.0/929.8 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/929.8 kB ? eta -:--:--
#    ---------------------- ----------------- 524.3/929.8 kB 1.4 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/929.8 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 929.8/929.8 kB 71.3 kB/s  0:00:09
# Downloading anyio-4.14.0-py3-none-any.whl (123 kB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading docstring_parser-0.18.0-py3-none-any.whl (22 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading jiter-0.15.0-cp314-cp314-win_amd64.whl (197 kB)
# Downloading pydantic-2.13.4-py3-none-any.whl (472 kB)
# Downloading pydantic_core-2.46.4-cp314-cp314-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB ? eta -:--:--
#    --------------- ------------------------ 0.8/2.1 MB 1.8 MB/s eta 0:00:01
#    -------------------- ------------------- 1.0/2.1 MB 2.0 MB/s eta 0:00:01
#    ------------------------- -------------- 1.3/2.1 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.8/2.1 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 1.7 MB/s  0:00:01
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading idna-3.18-py3-none-any.whl (65 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading certifi-2026.6.17-py3-none-any.whl (133 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: typing-inspection, sniffio, python-dotenv, pydantic-core, jiter, idna, h11, docstring-parser, distro, certifi, annotated-types, pydantic, httpcore, anyio, httpx, anthropic
#
#    -- -------------------------------------  1/16 [sniffio]
#    ----- ----------------------------------  2/16 [python-dotenv]
#    ------- --------------------------------  3/16 [pydantic-core]
#    ------------ ---------------------------  5/16 [idna]
#    ------------ ---------------------------  5/16 [idna]
#    --------------- ------------------------  6/16 [h11]
#    ----------------- ----------------------  7/16 [docstring-parser]
#    -------------------- -------------------  8/16 [distro]
#    --------------------------- ------------ 11/16 [pydantic]
#    --------------------------- ------------ 11/16 [pydantic]
#    --------------------------- ------------ 11/16 [pydantic]
#    --------------------------- ------------ 11/16 [pydantic]
#    --------------------------- ------------ 11/16 [pydantic]
#    --------------------------- ------------ 11/16 [pydantic]
#    --------------------------- ------------ 11/16 [pydantic]
#    --------------------------- ------------ 11/16 [pydantic]
#    --------------------------- ------------ 11/16 [pydantic]
#    --------------------------- ------------ 11/16 [pydantic]
#    --------------------------- ------------ 11/16 [pydantic]
#    --------------------------- ------------ 11/16 [pydantic]
#    --------------------------- ------------ 11/16 [pydantic]
#    --------------------------- ------------ 11/16 [pydantic]
#    --------------------------- ------------ 11/16 [pydantic]
#    --------------------------- ------------ 11/16 [pydantic]
#    ------------------------------ --------- 12/16 [httpcore]
#    ------------------------------ --------- 12/16 [httpcore]
#    ------------------------------ --------- 12/16 [httpcore]
#    ------------------------------ --------- 12/16 [httpcore]
#    ------------------------------ --------- 12/16 [httpcore]
#    -------------------------------- ------- 13/16 [anyio]
#    -------------------------------- ------- 13/16 [anyio]
#    -------------------------------- ------- 13/16 [anyio]
#    -------------------------------- ------- 13/16 [anyio]
#    -------------------------------- ------- 13/16 [anyio]
#    -------------------------------- ------- 13/16 [anyio]
#    -------------------------------- ------- 13/16 [anyio]
#    -------------------------------- ------- 13/16 [anyio]
#    ----------------------------------- ---- 14/16 [httpx]
#    ----------------------------------- ---- 14/16 [httpx]
#    ----------------------------------- ---- 14/16 [httpx]
#    ----------------------------------- ---- 14/16 [httpx]
#    ----------------------------------- ---- 14/16 [httpx]
#    ----------------------------------- ---- 14/16 [httpx]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ------------------------------------- -- 15/16 [anthropic]
#    ---------------------------------------- 16/16 [anthropic]
#
# Successfully installed annotated-types-0.7.0 anthropic-0.111.0 anyio-4.14.0 certifi-2026.6.17 distro-1.9.0 docstring-parser-0.18.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.18 jiter-0.15.0 pydantic-2.13.4 pydantic-core-2.46.4 python-dotenv-1.2.2 sniffio-1.3.1 typing-inspection-0.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
import os
load_dotenv()

if os.getenv("ANTHROPIC_API_KEY") is None: 
    raise Exception("api key not found")

# %%
from anthropic import Anthropic

client = Anthropic()
model= "claude-haiku-4-5-20251001"

# %%
def add_user_message(messages, user_prompt):
    messages.append({"role" : "user", "content" :user_prompt})

def add_assistant_message(messages, assistant_prompt):
    messages.append({"role" : "assistant", "content" :assistant_prompt})

def chat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }
    
    if system:
        params["system"] = system
    
    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []
add_user_message(messages, "what is the meaning of life?")
assistant_response = chat(messages, "you should always answer in single sentence")
add_assistant_message(messages,assistant_response)
print(messages)
# Out:
# [{'role': 'user', 'content': 'what is the meaning of life?'}, {'role': 'assistant', 'content': 'The meaning of life is ultimately subjective and personal—shaped by your own values, relationships, achievements, growth, and contributions to others rather than having one universal answer.'}]

# %%
messages = []
add_user_message(messages,"what is the meaning of life?")
params = {
      "model" : model,
    "max_tokens" : 100,
    "messages" :  messages
}
with client.messages.stream(**params) as stream: 
    for text in stream.text_stream:
        # print(text,end = "")
        pass

stream.get_final_message().content[0].text
# Out:
# "That's one of humanity's oldest questions, and there's no single answer—it varies deeply by person.\n\nSome common perspectives:\n\n**Philosophical views:**\n- Creating your own meaning through choices and actions\n- Pursuing knowledge, beauty, or truth\n- Reducing suffering (your own and others')\n\n**Religious/spiritual approaches:**\n- Serving a higher purpose or deity\n- Spiritual growth or enlightenment\n\n**Practical answers people often find:**\n-"
